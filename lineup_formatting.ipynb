# %%
# unpacking json file

import pandas as pd
import json

# %%
with open('prem_2024_data.json') as f:
    d = json.load(f)

# %%
len(d['lineups']) #['0'][0]
# Out:
# 349

# %%
fixture_info_list = []

for i in range(len(d['fixture'])):
    index = str(i)

    fixture_info = {
    "fixture_id": d['fixture'][index]['id'],
    "country": d['league'][index]['country'],
    "competition": d['league'][index]['name'],
    "home_team": d['teams'][index]['home']['name'],
    "away_team": d['teams'][index]['away']['name'],
    "home_formation": d['lineups'][index][0]['formation'],
    "away_formation": d['lineups'][index][1]['formation'],
    "home_start_xi" : d['lineups'][index][0]['startXI'],
    "away_start_xi": d['lineups'][index][1]['startXI'],
    "home_subs": d['lineups'][index][0]['substitutes'],
    "away_subs": d['lineups'][index][0]['substitutes']
    }

    fixture_info_list.append(fixture_info)

df = pd.DataFrame(fixture_info_list)

# Step 1: Combine starters and subs into full squads
df['home_squad'] = df['home_start_xi'] + df['home_subs']
df['away_squad'] = df['away_start_xi'] + df['away_subs']

# Step 2: Loop through fixtures and build rows
squad_rows = []

for _, row in df.iterrows():
    fixture_id = row['fixture_id']
    home_team = row['home_team']
    away_team = row['away_team']
    competition = row['competition']
    home_formation = row['home_formation']
    away_formation = row['away_formation']

    home_squad = row['home_squad']
    away_squad = row['away_squad']
    
    max_len = max(len(home_squad), len(away_squad))
    
    for i in range(max_len):
        home_player = home_squad[i] if i < len(home_squad) else {}
        away_player = away_squad[i] if i < len(away_squad) else {}

        squad_rows.append({
            'fixture_id': fixture_id,
            'competition': competition,
            'player_slot': i + 1,
            'home_team': home_team,
            'home_formation': home_formation,
            'home_player_name': home_player.get('player', {}).get('name'),
            'home_player_number': home_player.get('player', {}).get('number'),
            'home_player_pos': home_player.get('player', {}).get('pos'),
            'home_player_grid': home_player.get('player', {}).get('grid'),
            'away_team': away_team,
            'away_formation': away_formation,
            'away_player_name': away_player.get('player', {}).get('name'),
            'away_player_number': away_player.get('player', {}).get('number'),
            'away_player_pos': away_player.get('player', {}).get('pos'),
            'away_player_grid': away_player.get('player', {}).get('grid'),
        })

# Step 3: Final squad-level DataFrame
df_squads = pd.DataFrame(squad_rows)

# %%
rows = []
# assume d['fixture'], d['league'], d['teams'] & d['lineups'] are all dicts keyed by the same strings
for key, fix in d['fixture'].items():
    league = d['league'][key]
    teams  = d['teams'][key]
    lineups = d['lineups'][key]  # [ home_lineup, away_lineup ]

    for side, lineup in zip(['home','away'], lineups):
        full_squad = lineup['startXI'] + lineup['substitutes']
        for slot, pl in enumerate(full_squad, start=1):
            rows.append({
                'fixture_id':   fix['id'],
                'country':      league['country'],
                'competition':  league['name'],
                'team_side':    side,                    # 'home' or 'away'
                'team_name':    teams[side]['name'],
                'formation':    lineup['formation'],
                'player_slot':  slot,
                'player_name':  pl['player']['name'],
                'player_number':pl['player']['number'],
                'player_pos':   pl['player']['pos'],
                'player_grid':  pl['player']['grid']
            })

df_squads = pd.DataFrame(rows)

# %%
df_squads
# Out:
#        fixture_id  country     competition team_side          team_name  \
# 0         1208021  England  Premier League      home  Manchester United
# 1         1208021  England  Premier League      home  Manchester United
# 2         1208021  England  Premier League      home  Manchester United
# 3         1208021  England  Premier League      home  Manchester United
# 4         1208021  England  Premier League      home  Manchester United
# ...           ...      ...             ...       ...                ...
# 13945     1208372  England  Premier League      away          Tottenham
# 13946     1208372  England  Premier League      away          Tottenham
# 13947     1208372  England  Premier League      away          Tottenham
# 13948     1208372  England  Premier League      away          Tottenham
# 13949     1208372  England  Premier League      away          Tottenham
#
#       formation  player_slot        player_name  player_number player_pos  \
# 0       4-2-3-1            1           A. Onana             24          G
# 1       4-2-3-1            2        N. Mazraoui              3          D
# 2       4-2-3-1            3         H. Maguire              5          D
# 3       4-2-3-1            4  Lisandro Martínez              6          D
# 4       4-2-3-1            5        Diogo Dalot             20          D
# ...         ...          ...                ...            ...        ...
# 13945     4-3-3           16    Cristian Romero             17          D
# 13946     4-3-3           17   Micky van de Ven             37          D
# 13947     4-3-3           18  Rodrigo Bentancur             30          M
# 13948     4-3-3           19    Brennan Johnson             22          F
# 13949     4-3-3           20   Oyindamola Ajayi             63          F
#
#       player_grid
# 0             1:1
# 1             2:4
# 2             2:3
# 3             2:2
# 4             2:1
# ...           ...
# 13945        None
# 13946        None
# 13947        None
# 13948        None
# 13949        None
#
# [13950 rows x 11 columns]

# %%
df_squads.to_csv("data/data/fbref_dashboard/prem_24_lineups_long.csv")

# %%
import numpy as np
X_MIN = 10
Y_MIN = 10
X_MAX = 50
Y_MAX = 70

def players_plotting_coords(df, home_team, away_team):

    tidy = df[
    (df['away_team'] == away_team) &
    (df['home_team'] == home_team) &
    (df['home_player_grid'].str.contains(":", na=False))
    ].copy()
    
    tidy[["xplot","yplot"]] = tidy["home_player_grid"].str.split(':', expand = True)
    tidy['xplot'] = tidy['xplot'].astype(float)
    tidy['yplot'] = tidy['yplot'].astype(float)
    tidy['home_formation_list'] = tidy['home_formation'].str.split('-').to_list()
    tidy['xplot'] = X_MIN + (tidy['xplot'] - 1) * (X_MAX - X_MIN) / tidy['home_formation_list'].apply(len)
    # Calculate max yplot per xplot
    max_y_per_x = tidy.groupby("xplot")["yplot"].transform("max")

    # Apply scaling using per-x max values
    tidy['yplot'] = np.where(
        tidy['home_player_pos'] == "G",
        40,  # fixed value for goalkeeper
        Y_MIN + ((tidy['yplot'] - 1) * (Y_MAX - Y_MIN) / (max_y_per_x-1) )
    )
    return tidy

output_df = players_plotting_coords(df_squads, "Crystal Palace","Fulham")

# %%
output_df
# Out:
#       fixture_id     competition  player_slot       home_team home_formation  \
# 2057     1208126  Premier League            1  Crystal Palace        3-4-2-1
# 2058     1208126  Premier League            2  Crystal Palace        3-4-2-1
# 2059     1208126  Premier League            3  Crystal Palace        3-4-2-1
# 2060     1208126  Premier League            4  Crystal Palace        3-4-2-1
# 2061     1208126  Premier League            5  Crystal Palace        3-4-2-1
# 2062     1208126  Premier League            6  Crystal Palace        3-4-2-1
# 2063     1208126  Premier League            7  Crystal Palace        3-4-2-1
# 2064     1208126  Premier League            8  Crystal Palace        3-4-2-1
# 2065     1208126  Premier League            9  Crystal Palace        3-4-2-1
# 2066     1208126  Premier League           10  Crystal Palace        3-4-2-1
# 2067     1208126  Premier League           11  Crystal Palace        3-4-2-1
#
#      home_player_name  home_player_number home_player_pos home_player_grid  \
# 2057     D. Henderson                   1               G              1:1
# 2058      T. Chalobah                  27               D              2:3
# 2059       M. Lacroix                   5               D              2:2
# 2060         N. Clyne                  17               D              2:1
# 2061         D. Muñoz                  12               M              3:4
# 2062         M. Guéhi                   6               M              3:3
# 2063       J. Devenny                  55               M              3:2
# 2064      T. Mitchell                   3               M              3:1
# 2065        D. Kamada                  18               F              4:2
# 2066          I. Sarr                   7               F              4:1
# 2067        J. Mateta                  14               F              5:1
#
#      away_team away_formation away_player_name  away_player_number  \
# 2057    Fulham        4-2-3-1          B. Leno                   1
# 2058    Fulham        4-2-3-1          K. Tete                   2
# 2059    Fulham        4-2-3-1      J. Andersen                   5
# 2060    Fulham        4-2-3-1        C. Bassey                   3
# 2061    Fulham        4-2-3-1      A. Robinson                  33
# 2062    Fulham        4-2-3-1  Andreas Pereira                  18
# 2063    Fulham        4-2-3-1         S. Berge                  16
# 2064    Fulham        4-2-3-1         A. Iwobi                  17
# 2065    Fulham        4-2-3-1    E. Smith Rowe                  32
# 2066    Fulham        4-2-3-1        R. Nelson                  19
# 2067    Fulham        4-2-3-1       R. Jiménez                   7
#
#      away_player_pos away_player_grid  xplot  yplot home_formation_list
# 2057               G              1:1   10.0   40.0        [3, 4, 2, 1]
# 2058               D              2:4   20.0   70.0        [3, 4, 2, 1]
# 2059               D              2:3   20.0   40.0        [3, 4, 2, 1]
# 2060               D              2:2   20.0   10.0        [3, 4, 2, 1]
# 2061               D              2:1   30.0   70.0        [3, 4, 2, 1]
# 2062               M              3:2   30.0   50.0        [3, 4, 2, 1]
# 2063               M              3:1   30.0   30.0        [3, 4, 2, 1]
# 2064               M              4:3   30.0   10.0        [3, 4, 2, 1]
# 2065               M              4:2   40.0   70.0        [3, 4, 2, 1]
# 2066               M              4:1   40.0   10.0        [3, 4, 2, 1]
# 2067               F              5:1   50.0    NaN        [3, 4, 2, 1]

# %%
fixture_df = pd.DataFrame(d['fixture'])
fixture_df_melt = fixture_df.melt()

# %%
fixture_df_melt.iloc[6]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/94/9msgjwgn19x22gxt2y926v340000gn/T/ipykernel_57717/1237406923.py in ?()
# ----> 1 fixture_df_melt.iloc[6].json()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'json'

# %%
lineup_df = pd.DataFrame(d['lineups'])

# %%
lineup_df.melt()
# Out:
#     variable                                              value
# 0          0  {'team': {'id': 33, 'name': 'Manchester United...
# 1          0  {'team': {'id': 36, 'name': 'Fulham', 'logo': ...
# 2          1  {'team': {'id': 57, 'name': 'Ipswich', 'logo':...
# 3          1  {'team': {'id': 40, 'name': 'Liverpool', 'logo...
# 4          2  {'team': {'id': 42, 'name': 'Arsenal', 'logo':...
# ..       ...                                                ...
# 693      346  {'team': {'id': 41, 'name': 'Southampton', 'lo...
# 694      347  {'team': {'id': 50, 'name': 'Manchester City',...
# 695      347  {'team': {'id': 39, 'name': 'Wolves', 'logo': ...
# 696      348  {'team': {'id': 48, 'name': 'West Ham', 'logo'...
# 697      348  {'team': {'id': 47, 'name': 'Tottenham', 'logo...
#
# [698 rows x 2 columns]

# %%
test_df = test_df.melt()

# %%
test_2 = pd.json_normalize(test_df['value'])

# %%
test_2
# Out:
#     formation                                            startXI  \
# 0     4-2-3-1  [{'player': {'id': 526, 'name': 'A. Onana', 'n...
# 1     4-2-3-1  [{'player': {'id': 1438, 'name': 'B. Leno', 'n...
# 2     4-2-3-1  [{'player': {'id': 19541, 'name': 'C. Walton',...
# 3     4-2-3-1  [{'player': {'id': 280, 'name': 'Alisson Becke...
# 4       4-3-3  [{'player': {'id': 19465, 'name': 'David Raya'...
# ..        ...                                                ...
# 693   3-4-2-1  [{'player': {'id': 20355, 'name': 'Aaron Ramsd...
# 694   4-2-3-1  [{'player': {'id': 617, 'name': 'Ederson', 'nu...
# 695   3-4-2-1  [{'player': {'id': 1590, 'name': 'José Sá', 'n...
# 696   3-4-2-1  [{'player': {'id': 253, 'name': 'Alphonse Aréo...
# 697     4-3-3  [{'player': {'id': 31354, 'name': 'Guglielmo V...
#
#                                            substitutes  team.id  \
# 0    [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 1    [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 2    [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 3    [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 4    [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# ..                                                 ...      ...
# 693  [{'player': {'id': 304317, 'name': 'Tyler Dibl...       41
# 694  [{'player': {'id': 5, 'name': 'Manuel Akanji',...       50
# 695  [{'player': {'id': 2056, 'name': 'Pablo Sarabi...       39
# 696  [{'player': {'id': 1231, 'name': 'Vladimír Cou...       48
# 697  [{'player': {'id': 380690, 'name': 'Mikey Moor...       47
#
#              team.name                                          team.logo  \
# 0    Manchester United  https://media.api-sports.io/football/teams/33.png
# 1               Fulham  https://media.api-sports.io/football/teams/36.png
# 2              Ipswich  https://media.api-sports.io/football/teams/57.png
# 3            Liverpool  https://media.api-sports.io/football/teams/40.png
# 4              Arsenal  https://media.api-sports.io/football/teams/42.png
# ..                 ...                                                ...
# 693        Southampton  https://media.api-sports.io/football/teams/41.png
# 694    Manchester City  https://media.api-sports.io/football/teams/50.png
# 695             Wolves  https://media.api-sports.io/football/teams/39.png
# 696           West Ham  https://media.api-sports.io/football/teams/48.png
# 697          Tottenham  https://media.api-sports.io/football/teams/47.png
#
#     team.colors.player.primary team.colors.player.number  \
# 0                       ea0000                    ffffff
# 1                       ffffff                    000000
# 2                       0055aa                    ffffff
# 3                       e41e2c                    ffffff
# 4                       e10000                    ffffff
# ..                         ...                       ...
# 693                     c4ea87                    000000
# 694                     abd1f5                    ffffff
# 695                     fecd32                    000000
# 696                     74112e                    ffffff
# 697                     ffffff                    001e6c
#
#     team.colors.player.border team.colors.goalkeeper.primary  \
# 0                      ea0000                         000000
# 1                      ffffff                         d01e2a
# 2                      0055aa                         0f0f0e
# 3                      e41e2c                         23262b
# 4                      e10000                         00d5ff
# ..                        ...                            ...
# 693                    c4ea87                         affd69
# 694                    abd1f5                         ee4665
# 695                    fecd32                         00c32b
# 696                    74112e                         d400ff
# 697                    ffffff                         fcee00
#
#     team.colors.goalkeeper.number team.colors.goalkeeper.border  coach.id  \
# 0                          ffffff                        000000    1993.0
# 1                          ffffff                        d01e2a      10.0
# 2                          000000                        0f0f0e   16556.0
# 3                          f3f5f0                        23262b    2006.0
# 4                          ffffff                        00d5ff    7248.0
# ..                            ...                           ...       ...
# 693                        ffffff                        affd69     600.0
# 694                        070707                        ee4665       NaN
# 695                        ffffff                        00c32b       NaN
# 696                        ffffff                        d400ff      12.0
# 697                        131314                        fcee00     548.0
#
#          coach.name                                        coach.photo
# 0        E. ten Hag  https://media.api-sports.io/football/coachs/19...
# 1       Marco Silva  https://media.api-sports.io/football/coachs/10...
# 2        K. McKenna  https://media.api-sports.io/football/coachs/16...
# 3           A. Slot  https://media.api-sports.io/football/coachs/20...
# 4      Mikel Arteta  https://media.api-sports.io/football/coachs/72...
# ..              ...                                                ...
# 693         S. Rusk  https://media.api-sports.io/football/coachs/60...
# 694            None                                                NaN
# 695            None                                                NaN
# 696       G. Potter  https://media.api-sports.io/football/coachs/12...
# 697  A. Postecoglou  https://media.api-sports.io/football/coachs/54...
#
# [698 rows x 15 columns]

# %%
import pandas as pd

# assume test_df has columns: team, coach, formation, startXI, substitutes

def explode_role(df, list_col, role_name):
    # 1. explode the chosen list
    exploded = df.explode(list_col).reset_index(drop=True)
    # 2. flatten team & coach
    team_flat  = pd.json_normalize(exploded["team.name"]).add_prefix("team_")
    coach_flat = pd.json_normalize(exploded["coach.name"]).add_prefix("coach_")
    # 3. flatten the player dict
    play_flat  = pd.json_normalize(exploded[list_col]).add_prefix("player_")
    # 4. stitch back together, drop old columns, tag role
    base = exploded.drop(columns=["team.name","coach.name", list_col])
    out  = pd.concat([base, team_flat, coach_flat, play_flat], axis=1)
    out["role"] = role_name
    return out

# build two tables…
starters = explode_role(test_2, "startXI",    role_name="starter")
subs     = explode_role(test_2, "substitutes", role_name="sub")

# …and glue them into one
players = pd.concat([starters, subs], ignore_index=True)

# %%
players.head(50)
# Out:
#    formation                                        substitutes  team.id  \
# 0    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 1    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 2    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 3    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 4    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 5    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 6    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 7    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 8    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 9    4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 10   4-2-3-1  [{'player': {'id': 284324, 'name': 'A. Garnach...       33
# 11   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 12   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 13   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 14   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 15   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 16   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 17   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 18   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 19   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 20   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 21   4-2-3-1  [{'player': {'id': 19025, 'name': 'T. Cairney'...       36
# 22   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 23   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 24   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 25   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 26   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 27   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 28   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 29   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 30   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 31   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 32   4-2-3-1  [{'player': {'id': 18823, 'name': 'B. Johnson'...       57
# 33   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 34   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 35   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 36   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 37   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 38   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 39   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 40   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 41   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 42   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 43   4-2-3-1  [{'player': {'id': 1145, 'name': 'I. Konaté', ...       40
# 44     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# 45     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# 46     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# 47     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# 48     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
# 49     4-3-3  [{'player': {'id': 38746, 'name': 'J. Timber',...       42
#
#                                             team.logo  \
# 0   https://media.api-sports.io/football/teams/33.png
# 1   https://media.api-sports.io/football/teams/33.png
# 2   https://media.api-sports.io/football/teams/33.png
# 3   https://media.api-sports.io/football/teams/33.png
# 4   https://media.api-sports.io/football/teams/33.png
# 5   https://media.api-sports.io/football/teams/33.png
# 6   https://media.api-sports.io/football/teams/33.png
# 7   https://media.api-sports.io/football/teams/33.png
# 8   https://media.api-sports.io/football/teams/33.png
# 9   https://media.api-sports.io/football/teams/33.png
# 10  https://media.api-sports.io/football/teams/33.png
# 11  https://media.api-sports.io/football/teams/36.png
# 12  https://media.api-sports.io/football/teams/36.png
# 13  https://media.api-sports.io/football/teams/36.png
# 14  https://media.api-sports.io/football/teams/36.png
# 15  https://media.api-sports.io/football/teams/36.png
# 16  https://media.api-sports.io/football/teams/36.png
# 17  https://media.api-sports.io/football/teams/36.png
# 18  https://media.api-sports.io/football/teams/36.png
# 19  https://media.api-sports.io/football/teams/36.png
# 20  https://media.api-sports.io/football/teams/36.png
# 21  https://media.api-sports.io/football/teams/36.png
# 22  https://media.api-sports.io/football/teams/57.png
# 23  https://media.api-sports.io/football/teams/57.png
# 24  https://media.api-sports.io/football/teams/57.png
# 25  https://media.api-sports.io/football/teams/57.png
# 26  https://media.api-sports.io/football/teams/57.png
# 27  https://media.api-sports.io/football/teams/57.png
# 28  https://media.api-sports.io/football/teams/57.png
# 29  https://media.api-sports.io/football/teams/57.png
# 30  https://media.api-sports.io/football/teams/57.png
# 31  https://media.api-sports.io/football/teams/57.png
# 32  https://media.api-sports.io/football/teams/57.png
# 33  https://media.api-sports.io/football/teams/40.png
# 34  https://media.api-sports.io/football/teams/40.png
# 35  https://media.api-sports.io/football/teams/40.png
# 36  https://media.api-sports.io/football/teams/40.png
# 37  https://media.api-sports.io/football/teams/40.png
# 38  https://media.api-sports.io/football/teams/40.png
# 39  https://media.api-sports.io/football/teams/40.png
# 40  https://media.api-sports.io/football/teams/40.png
# 41  https://media.api-sports.io/football/teams/40.png
# 42  https://media.api-sports.io/football/teams/40.png
# 43  https://media.api-sports.io/football/teams/40.png
# 44  https://media.api-sports.io/football/teams/42.png
# 45  https://media.api-sports.io/football/teams/42.png
# 46  https://media.api-sports.io/football/teams/42.png
# 47  https://media.api-sports.io/football/teams/42.png
# 48  https://media.api-sports.io/football/teams/42.png
# 49  https://media.api-sports.io/football/teams/42.png
#
#    team.colors.player.primary team.colors.player.number  \
# 0                      ea0000                    ffffff
# 1                      ea0000                    ffffff
# 2                      ea0000                    ffffff
# 3                      ea0000                    ffffff
# 4                      ea0000                    ffffff
# 5                      ea0000                    ffffff
# 6                      ea0000                    ffffff
# 7                      ea0000                    ffffff
# 8                      ea0000                    ffffff
# 9                      ea0000                    ffffff
# 10                     ea0000                    ffffff
# 11                     ffffff                    000000
# 12                     ffffff                    000000
# 13                     ffffff                    000000
# 14                     ffffff                    000000
# 15                     ffffff                    000000
# 16                     ffffff                    000000
# 17                     ffffff                    000000
# 18                     ffffff                    000000
# 19                     ffffff                    000000
# 20                     ffffff                    000000
# 21                     ffffff                    000000
# 22                     0055aa                    ffffff
# 23                     0055aa                    ffffff
# 24                     0055aa                    ffffff
# 25                     0055aa                    ffffff
# 26                     0055aa                    ffffff
# 27                     0055aa                    ffffff
# 28                     0055aa                    ffffff
# 29                     0055aa                    ffffff
# 30                     0055aa                    ffffff
# 31                     0055aa                    ffffff
# 32                     0055aa                    ffffff
# 33                     e41e2c                    ffffff
# 34                     e41e2c                    ffffff
# 35                     e41e2c                    ffffff
# 36                     e41e2c                    ffffff
# 37                     e41e2c                    ffffff
# 38                     e41e2c                    ffffff
# 39                     e41e2c                    ffffff
# 40                     e41e2c                    ffffff
# 41                     e41e2c                    ffffff
# 42                     e41e2c                    ffffff
# 43                     e41e2c                    ffffff
# 44                     e10000                    ffffff
# 45                     e10000                    ffffff
# 46                     e10000                    ffffff
# 47                     e10000                    ffffff
# 48                     e10000                    ffffff
# 49                     e10000                    ffffff
#
#    team.colors.player.border team.colors.goalkeeper.primary  \
# 0                     ea0000                         000000
# 1                     ea0000                         000000
# 2                     ea0000                         000000
# 3                     ea0000                         000000
# 4                     ea0000                         000000
# 5                     ea0000                         000000
# 6                     ea0000                         000000
# 7                     ea0000                         000000
# 8                     ea0000                         000000
# 9                     ea0000                         000000
# 10                    ea0000                         000000
# 11                    ffffff                         d01e2a
# 12                    ffffff                         d01e2a
# 13                    ffffff                         d01e2a
# 14                    ffffff                         d01e2a
# 15                    ffffff                         d01e2a
# 16                    ffffff                         d01e2a
# 17                    ffffff                         d01e2a
# 18                    ffffff                         d01e2a
# 19                    ffffff                         d01e2a
# 20                    ffffff                         d01e2a
# 21                    ffffff                         d01e2a
# 22                    0055aa                         0f0f0e
# 23                    0055aa                         0f0f0e
# 24                    0055aa                         0f0f0e
# 25                    0055aa                         0f0f0e
# 26                    0055aa                         0f0f0e
# 27                    0055aa                         0f0f0e
# 28                    0055aa                         0f0f0e
# 29                    0055aa                         0f0f0e
# 30                    0055aa                         0f0f0e
# 31                    0055aa                         0f0f0e
# 32                    0055aa                         0f0f0e
# 33                    e41e2c                         23262b
# 34                    e41e2c                         23262b
# 35                    e41e2c                         23262b
# 36                    e41e2c                         23262b
# 37                    e41e2c                         23262b
# 38                    e41e2c                         23262b
# 39                    e41e2c                         23262b
# 40                    e41e2c                         23262b
# 41                    e41e2c                         23262b
# 42                    e41e2c                         23262b
# 43                    e41e2c                         23262b
# 44                    e10000                         00d5ff
# 45                    e10000                         00d5ff
# 46                    e10000                         00d5ff
# 47                    e10000                         00d5ff
# 48                    e10000                         00d5ff
# 49                    e10000                         00d5ff
#
#    team.colors.goalkeeper.number team.colors.goalkeeper.border  coach.id  \
# 0                         ffffff                        000000    1993.0
# 1                         ffffff                        000000    1993.0
# 2                         ffffff                        000000    1993.0
# 3                         ffffff                        000000    1993.0
# 4                         ffffff                        000000    1993.0
# 5                         ffffff                        000000    1993.0
# 6                         ffffff                        000000    1993.0
# 7                         ffffff                        000000    1993.0
# 8                         ffffff                        000000    1993.0
# 9                         ffffff                        000000    1993.0
# 10                        ffffff                        000000    1993.0
# 11                        ffffff                        d01e2a      10.0
# 12                        ffffff                        d01e2a      10.0
# 13                        ffffff                        d01e2a      10.0
# 14                        ffffff                        d01e2a      10.0
# 15                        ffffff                        d01e2a      10.0
# 16                        ffffff                        d01e2a      10.0
# 17                        ffffff                        d01e2a      10.0
# 18                        ffffff                        d01e2a      10.0
# 19                        ffffff                        d01e2a      10.0
# 20                        ffffff                        d01e2a      10.0
# 21                        ffffff                        d01e2a      10.0
# 22                        000000                        0f0f0e   16556.0
# 23                        000000                        0f0f0e   16556.0
# 24                        000000                        0f0f0e   16556.0
# 25                        000000                        0f0f0e   16556.0
# 26                        000000                        0f0f0e   16556.0
# 27                        000000                        0f0f0e   16556.0
# 28                        000000                        0f0f0e   16556.0
# 29                        000000                        0f0f0e   16556.0
# 30                        000000                        0f0f0e   16556.0
# 31                        000000                        0f0f0e   16556.0
# 32                        000000                        0f0f0e   16556.0
# 33                        f3f5f0                        23262b    2006.0
# 34                        f3f5f0                        23262b    2006.0
# 35                        f3f5f0                        23262b    2006.0
# 36                        f3f5f0                        23262b    2006.0
# 37                        f3f5f0                        23262b    2006.0
# 38                        f3f5f0                        23262b    2006.0
# 39                        f3f5f0                        23262b    2006.0
# 40                        f3f5f0                        23262b    2006.0
# 41                        f3f5f0                        23262b    2006.0
# 42                        f3f5f0                        23262b    2006.0
# 43                        f3f5f0                        23262b    2006.0
# 44                        ffffff                        00d5ff    7248.0
# 45                        ffffff                        00d5ff    7248.0
# 46                        ffffff                        00d5ff    7248.0
# 47                        ffffff                        00d5ff    7248.0
# 48                        ffffff                        00d5ff    7248.0
# 49                        ffffff                        00d5ff    7248.0
#
#                                           coach.photo  player_player.id  \
# 0   https://media.api-sports.io/football/coachs/19...               526
# 1   https://media.api-sports.io/football/coachs/19...               545
# 2   https://media.api-sports.io/football/coachs/19...              2935
# 3   https://media.api-sports.io/football/coachs/19...              2467
# 4   https://media.api-sports.io/football/coachs/19...               886
# 5   https://media.api-sports.io/football/coachs/19...               747
# 6   https://media.api-sports.io/football/coachs/19...            284322
# 7   https://media.api-sports.io/football/coachs/19...            157997
# 8   https://media.api-sports.io/football/coachs/19...             19220
# 9   https://media.api-sports.io/football/coachs/19...               909
# 10  https://media.api-sports.io/football/coachs/19...              1485
# 11  https://media.api-sports.io/football/coachs/10...              1438
# 12  https://media.api-sports.io/football/coachs/10...               657
# 13  https://media.api-sports.io/football/coachs/10...             18814
# 14  https://media.api-sports.io/football/coachs/10...            152967
# 15  https://media.api-sports.io/football/coachs/10...             19549
# 16  https://media.api-sports.io/football/coachs/10...               899
# 17  https://media.api-sports.io/football/coachs/10...              2823
# 18  https://media.api-sports.io/football/coachs/10...             18753
# 19  https://media.api-sports.io/football/coachs/10...              1161
# 20  https://media.api-sports.io/football/coachs/10...              1455
# 21  https://media.api-sports.io/football/coachs/10...            195106
# 22  https://media.api-sports.io/football/coachs/16...             19541
# 23  https://media.api-sports.io/football/coachs/16...             19182
# 24  https://media.api-sports.io/football/coachs/16...             17714
# 25  https://media.api-sports.io/football/coachs/16...            127579
# 26  https://media.api-sports.io/football/coachs/16...             19119
# 27  https://media.api-sports.io/football/coachs/16...             19558
# 28  https://media.api-sports.io/football/coachs/16...              2752
# 29  https://media.api-sports.io/football/coachs/16...             20089
# 30  https://media.api-sports.io/football/coachs/16...             20007
# 31  https://media.api-sports.io/football/coachs/16...            284428
# 32  https://media.api-sports.io/football/coachs/16...            161948
# 33  https://media.api-sports.io/football/coachs/20...               280
# 34  https://media.api-sports.io/football/coachs/20...               283
# 35  https://media.api-sports.io/football/coachs/20...            158698
# 36  https://media.api-sports.io/football/coachs/20...               290
# 37  https://media.api-sports.io/football/coachs/20...               289
# 38  https://media.api-sports.io/football/coachs/20...               542
# 39  https://media.api-sports.io/football/coachs/20...              6716
# 40  https://media.api-sports.io/football/coachs/20...               306
# 41  https://media.api-sports.io/football/coachs/20...              1096
# 42  https://media.api-sports.io/football/coachs/20...              2489
# 43  https://media.api-sports.io/football/coachs/20...              2678
# 44  https://media.api-sports.io/football/coachs/72...             19465
# 45  https://media.api-sports.io/football/coachs/72...             19959
# 46  https://media.api-sports.io/football/coachs/72...             22090
# 47  https://media.api-sports.io/football/coachs/72...             22224
# 48  https://media.api-sports.io/football/coachs/72...               641
# 49  https://media.api-sports.io/football/coachs/72...             37127
#
#      player_player.name  player_player.number player_player.pos  \
# 0              A. Onana                    24                 G
# 1           N. Mazraoui                     3                 D
# 2            H. Maguire                     5                 D
# 3     Lisandro Martínez                     6                 D
# 4           Diogo Dalot                    20                 D
# 5              Casemiro                    18                 M
# 6             K. Mainoo                    37                 M
# 7             A. Diallo                    16                 M
# 8              M. Mount                     7                 M
# 9           M. Rashford                    10                 M
# 10      Bruno Fernandes                     8                 F
# 11              B. Leno                     1                 G
# 12              K. Tete                     2                 D
# 13              I. Diop                    31                 D
# 14            C. Bassey                     3                 D
# 15          A. Robinson                    33                 D
# 16      Andreas Pereira                    18                 M
# 17             S. Lukić                    20                 M
# 18         Adama Traoré                    11                 M
# 19        E. Smith Rowe                    32                 M
# 20             A. Iwobi                    17                 M
# 21        Rodrigo Muniz                     9                 F
# 22            C. Walton                    28                 G
# 23          A. Tuanzebe                    40                 D
# 24        L. Woolfenden                     6                 D
# 25           J. Greaves                    24                 D
# 26             L. Davis                     3                 D
# 27            Sam Morsy                     5                 M
# 28            M. Luongo                    25                 M
# 29             W. Burns                     7                 M
# 30           C. Chaplin                    10                 M
# 31        O. Hutchinson                    20                 M
# 32             L. Delap                    19                 F
# 33       Alisson Becker                     1                 G
# 34  T. Alexander-Arnold                    66                 D
# 35           J. Quansah                    78                 D
# 36          V. van Dijk                     4                 D
# 37         A. Robertson                    26                 D
# 38       R. Gravenberch                    38                 M
# 39      A. Mac Allister                    10                 M
# 40        Mohamed Salah                    11                 M
# 41        D. Szoboszlai                     8                 M
# 42              L. Díaz                     7                 M
# 43           Diogo Jota                    20                 F
# 44           David Raya                    22                 G
# 45             B. White                     4                 D
# 46            W. Saliba                     2                 D
# 47    Gabriel Magalhães                     6                 D
# 48         O. Zinchenko                    17                 D
# 49          M. Ødegaard                     8                 M
#
#    player_player.grid     role startXI
# 0                 1:1  starter     NaN
# 1                 2:4  starter     NaN
# 2                 2:3  starter     NaN
# 3                 2:2  starter     NaN
# 4                 2:1  starter     NaN
# 5                 3:2  starter     NaN
# 6                 3:1  starter     NaN
# 7                 4:3  starter     NaN
# 8                 4:2  starter     NaN
# 9                 4:1  starter     NaN
# 10                5:1  starter     NaN
# 11                1:1  starter     NaN
# 12                2:4  starter     NaN
# 13                2:3  starter     NaN
# 14                2:2  starter     NaN
# 15                2:1  starter     NaN
# 16                3:2  starter     NaN
# 17                3:1  starter     NaN
# 18                4:3  starter     NaN
# 19                4:2  starter     NaN
# 20                4:1  starter     NaN
# 21                5:1  starter     NaN
# 22                1:1  starter     NaN
# 23                2:4  starter     NaN
# 24                2:3  starter     NaN
# 25                2:2  starter     NaN
# 26                2:1  starter     NaN
# 27                3:2  starter     NaN
# 28                3:1  starter     NaN
# 29                4:3  starter     NaN
# 30                4:2  starter     NaN
# 31                4:1  starter     NaN
# 32                5:1  starter     NaN
# 33                1:1  starter     NaN
# 34                2:4  starter     NaN
# 35                2:3  starter     NaN
# 36                2:2  starter     NaN
# 37                2:1  starter     NaN
# 38                3:2  starter     NaN
# 39                3:1  starter     NaN
# 40                4:3  starter     NaN
# 41                4:2  starter     NaN
# 42                4:1  starter     NaN
# 43                5:1  starter     NaN
# 44                1:1  starter     NaN
# 45                2:4  starter     NaN
# 46                2:3  starter     NaN
# 47                2:2  starter     NaN
# 48                2:1  starter     NaN
# 49                3:3  starter     NaN
